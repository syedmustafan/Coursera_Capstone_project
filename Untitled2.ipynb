# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# we import the libraries for request and BeautifulSoup
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html = urlopen(url)

# %%
dflst = pd.read_html(url,header =0)
df1 = dflst[0]
df1
# Out:
#     Postcode           Borough          Neighbourhood
# 0        M1A      Not assigned           Not assigned
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# ..       ...               ...                    ...
# 283      M8Z         Etobicoke              Mimico NW
# 284      M8Z         Etobicoke     The Queensway West
# 285      M8Z         Etobicoke  Royal York South West
# 286      M8Z         Etobicoke         South of Bloor
# 287      M9Z      Not assigned           Not assigned
#
# [288 rows x 3 columns]

# %%
df = df1[df1.Borough != 'Not assigned']

# %%
df[df.Neighbourhood == 'Not assigned']
# Out:
#   Postcode       Borough Neighbourhood
# 8      M7A  Queen's Park  Not assigned

# %%
df.loc[8,'Neighbourhood'] = "Queen's Park"
df[df.Neighbourhood == 'Not assigned']
# Out:
# c:\users\haris ali\anaconda3\envs\py3.5\lib\site-packages\pandas\core\indexing.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# c:\users\haris ali\anaconda3\envs\py3.5\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood]
# Index: []

# %%
df[df.duplicated(['Postcode'])].index
# Out:
# Int64Index([  5,   7,  12,  16,  18,  23,  24,  25,  26,  28,
#             ...
#             268, 269, 270, 271, 272, 273, 283, 284, 285, 286],
#            dtype='int64', length=108)

# %%
dfD = df[df.duplicated(['Postcode'])]

for idx, neigh in zip(dfD.index,dfD['Neighbourhood']):
    temp = df.loc[idx-1,'Neighbourhood']
    print(temp)
    df.loc[idx-1,"Neighbourhood"] = temp+','+neigh
# Out:
# Harbourfront
# Lawrence Heights
# Rouge
# Woodbine Gardens
# Ryerson
# Cloverdale
# Islington
# Martin Grove
# Princess Gardens
# Highland Creek
# Rouge Hill
# Flemingdon Park
# Bloordale Gardens
# Eringate
# Markland Wood
# Guildwood
# Morningside
# Bathurst Manor
# Downsview North
# Adelaide
# King
# Dovercourt Village
# Fairview
# Henry Farm
# Northwood Park
# Harbourfront East
# Toronto Islands
# Little Portugal
# East Birchmount Park
# Ionview
# CFB Toronto
# The Danforth West
# Design Exchange
# Brockton
# Exhibition Place
# Clairlea
# Golden Mile
# Silver Hills
# The Beaches West
# Commerce Court
# Downsview
# North Park
# Cliffcrest
# Cliffside
# Newtonbrook
# Bedford Park
# Del Ray
# Keelesdale
# Mount Dennis
# Emery
# Birch Cliff
# The Junction North
# Dorset Park
# Scarborough Town Centre
# Forest Hill North
# High Park
# Maryvale
# The Annex
# North Midtown
# Parkdale
# Kingsview Village
# Martin Grove Gardens
# Richview Gardens
# Harbord
# Runnymede
# Clarks Corners
# Sullivan
# Moore Park
# Chinatown
# Grange Park
# Agincourt North
# L'Amoreaux East
# Milliken
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# Humber Bay Shores
# Mimico South
# Albion Gardens
# Beaumond Heights
# Humbergate
# Jamestown
# Mount Olive
# Silverstone
# South Steeles
# Alderwood
# Cabbagetown
# First Canadian Place
# The Kingsway
# Montgomery Road
# Humber Bay
# King's Mill Park
# Kingsway Park South East
# Mimico NE
# Old Mill South
# The Queensway East
# Royal York South East
# Kingsway Park South West
# Mimico NW
# The Queensway West
# Royal York South West
# c:\users\haris ali\anaconda3\envs\py3.5\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop_duplicates(['Postcode'], keep='first', inplace=True)
df.head(30)
# Out:
# c:\users\haris ali\anaconda3\envs\py3.5\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Postcode           Borough                    Neighbourhood
# 2       M3A        North York                        Parkwoods
# 3       M4A        North York                 Victoria Village
# 4       M5A  Downtown Toronto         Harbourfront,Regent Park
# 6       M6A        North York  Lawrence Heights,Lawrence Manor
# 8       M7A      Queen's Park                     Queen's Park
# 10      M9A         Etobicoke                 Islington Avenue
# 11      M1B       Scarborough                    Rouge,Malvern
# 14      M3B        North York                  Don Mills North
# 15      M4B         East York   Woodbine Gardens,Parkview Hill
# 17      M5B  Downtown Toronto          Ryerson,Garden District
# 19      M6B        North York                        Glencairn
# 22      M9B         Etobicoke             Cloverdale,Islington
# 27      M1C       Scarborough        Highland Creek,Rouge Hill
# 31      M3C        North York  Flemingdon Park,Don Mills South
# 33      M4C         East York                 Woodbine Heights
# 34      M5C  Downtown Toronto                   St. James Town
# 35      M6C              York               Humewood-Cedarvale
# 38      M9C         Etobicoke       Bloordale Gardens,Eringate
# 42      M1E       Scarborough            Guildwood,Morningside
# 47      M4E      East Toronto                      The Beaches
# 48      M5E  Downtown Toronto                      Berczy Park
# 49      M6E              York              Caledonia-Fairbanks
# 53      M1G       Scarborough                           Woburn
# 56      M4G         East York                          Leaside
# 57      M5G  Downtown Toronto               Central Bay Street
# 58      M6G  Downtown Toronto                         Christie
# 62      M1H       Scarborough                        Cedarbrae
# 63      M2H        North York                Hillcrest Village
# 64      M3H        North York   Bathurst Manor,Downsview North
# 67      M4H         East York                 Thorncliffe Park

# %%
df.shape
# Out:
# (103, 3)
